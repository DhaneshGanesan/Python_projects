# %% [markdown]
# # Module 2: Exploration data analysis of visualization and training a model by given attributes

# %%
#import library packages
import pandas as p
import matplotlib.pyplot as plt

import seaborn as s
import numpy as n

# %%
data = p.read_csv("diabetes.csv")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.shape
# Out:
# (768, 9)

# %%
#diabates possitive reports
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#missing values
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data["Outcome"].value_counts()
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
data.shape
# Out:
# (768, 9)

# %% [markdown]
# ###

# %%
#missing values by heatmap
plt.figure(figsize=(8,6))
s.heatmap(data.isnull(),annot = True)
plt.show()

# %%
# diadbetes pesion with blood pressure 
plt.figure(figsize=(16,4))
plt.subplot(1,2,1)
plt.hist(data['BMI'])
plt.title("BMI")
plt.xlabel("BMI VRange")
plt.ylabel("count")
plt.subplot(1,2,2)
plt.hist(data['BloodPressure'])
plt.xlabel('BloodPressure')
plt.title('BloodPressure Range')
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(16,6))
s.countplot(x="Age",data=data)
plt.show()

# %%
# result based on age
plt.figure(figsize=(16,6))
s.countplot(x='Age',hue='Outcome',data=data)
plt.show()

# %%
plt.figure(figsize=(16,4))

plt.scatter(data['BMI'],data['Glucose'])
plt.xlabel("Age")
plt.ylabel("Glucose")
plt.show()

# %%
plt.figure(figsize=(16,4))

plt.scatter(data['BloodPressure'],data['Glucose'])
plt.xlabel('BloodPressure')
plt.ylabel("Glucose")
plt.show()

# %%
boxplot = data.boxplot(column = ['Glucose'], by = 'Outcome',figsize = (8,5), fontsize = 15)
plt.show()
boxplot = data.boxplot(column = ['BloodPressure'], by = 'Outcome',figsize = (8,5), fontsize = 15)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(14,10))
s.heatmap(data.corr(),annot = True, fmt='0.2%',cmap = 'Reds',ax=ax)
# Out:
# <AxesSubplot:>

# %%
s.boxplot(data['Glucose'])
plt.show()

s.boxplot(data["BloodPressure"])
plt.show()

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
#Propagation by variable
def PropByVar(df, variable):
    dataframe_pie = df[variable].value_counts()
    ax = dataframe_pie.plot.pie(figsize=(10,10), autopct='%1.2f%%', fontsize = 12)
    ax.set_title(variable + ' \n', fontsize = 15)
    return n.round(dataframe_pie/df.shape[0]*100,2)

PropByVar(data, 'Outcome')
# Out:
# 0    65.1
# 1    34.9
# Name: Outcome, dtype: float64

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
p.plotting.scatter_matrix(data, alpha=0.05, figsize=(18,10), diagonal='hist')
axis = 'off'

plt.show()

# %%
data.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
var_mod = ['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
       'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome']

for i in var_mod:
    data[i] = le.fit_transform(data[i].astype(int))

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  BMI  \
# 0            6       86             22             28        0   16
# 1            1       23             19             22        0    9
# 2            8      121             17              0        0    6
# 3            1       27             19             16       62   11
# 4            0       75              4             28      102   26
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                         0   29        1
# 1                         0   10        0
# 2                         0   11        1
# 3                         0    0        0
# 4                         2   12        1
